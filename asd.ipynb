# %%
import matplotlib.pyplot as plt

'''plt.plot([15.6, 14.2, 16.3, 18.2, 17.1, 20.2, 22.4])
plt.show()
'''

X = ["Mon", "Tue", "Wed", "Thur", "Fri", "Sat", "Sun"]
Y1 = [15.6, 14.2, 16.3, 18.2, 17, 20.2, 22.4]
Y2 = [20.1, 23.1, 23.8, 25.9, 23.4, 25.1, 26.3]

plt.plot(X, Y1,":b", label ="Seoul", color ="black")
plt.plot(X, Y2,":d", label ="Busan", color ="orange")
plt.xlabel("day")
plt.ylabel("Temperature") 
plt.legend(loc="upper left")
plt.title("Temperatures of Cities")
plt.show()

plt.bar(X,Y1)

plt.plot([1.6,142,13,182,1.1,202,2.4], "sm" )
plt.show()
# Out:
# C:\Users\202-03\AppData\Local\Temp\ipykernel_7048\3814154799.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ":b" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(X, Y1,":b", label ="Seoul", color ="black")
